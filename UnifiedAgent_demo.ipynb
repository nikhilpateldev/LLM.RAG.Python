# %% [markdown]
# # Unified RAG Agent Demo
# This notebook demonstrates all 4 RAG approaches.

# %%
from UnifiedAgent import UnifiedAgent
agent = UnifiedAgent()
# Out:
# UnifiedAgent ready. Approaches:
# B Conditional: True
# C Hybrid: True
# D Router: True
# E MultiQuery: True

# %%
agent.answer_conditional('How do I configure IIS?')
# Out:
# Debug
# Debug
# ...

# %%
agent.answer_hybrid('How to backup EC2?')
# Out:
# 1.1
# 1
# 1.2
# 1.3
# 1.4
# 1.5
# 1.6
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Users\Nikhil\anaconda3\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\Nikhil\anaconda3\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\Nikhil\anaconda3\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
# ...

# %%
agent.answer_router('What is my leave balance?')

# %%
agent.answer_multiquery('How do I renew policy after address change?')
